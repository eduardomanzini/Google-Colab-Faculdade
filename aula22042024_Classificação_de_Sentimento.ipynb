# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardomanzini/Google-Colab-faculdade/blob/main/aula22042024_Classifica%C3%A7%C3%A3o_de_Sentimento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Word2Vec**

# %%
import gensim.downloader as api

# Carregar embeddings Word2Vec pré-treinados
w2v_model = api.load("word2vec-google-news-300")

# Obter vetor de palavra para uma palavra específica
word_vector = w2v_model['apple']
print("Vetor Word2Vec para a palavra 'apple':", word_vector)

# Encontrar palavras mais similares
similar_words = w2v_model.most_similar('apple', topn=5)
print("Palavras mais similares a 'apple':", similar_words)
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded
# Vetor Word2Vec para a palavra 'apple': [-0.06445312 -0.16015625 -0.01208496  0.13476562 -0.22949219  0.16210938
#   0.3046875  -0.1796875  -0.12109375  0.25390625 -0.01428223 -0.06396484
#  -0.08056641 -0.05688477 -0.19628906  0.2890625  -0.05151367  0.14257812
#  -0.10498047 -0.04736328 -0.34765625  0.35742188  0.265625    0.00188446
#  -0.01586914  0.00195312 -0.35546875  0.22167969  0.05761719  0.15917969
#   0.08691406 -0.0267334  -0.04785156  0.23925781 -0.05981445  0.0378418
#   0.17382812 -0.41796875  0.2890625   0.32617188  0.02429199 -0.01647949
#  -0.06494141 -0.08886719  0.07666016 -0.15136719  0.05249023 -0.04199219
#  -0.05419922  0.00108337 -0.20117188  0.12304688  0.09228516  0.10449219
#  -0.00408936 -0.04199219  0.01409912 -0.02111816 -0.13476562 -0.24316406
#   0.16015625 -0.06689453 -0.08984375 -0.07177734 -0.00595093 -0.00482178
# ...

# %% [markdown]
# **GloVe**

# %%
import gensim.downloader as api

# Carregar embeddings GloVe pré-treinados
glove_model = api.load("glove-wiki-gigaword-100")

# Obter vetor de palavra para uma palavra específica
word_vector = glove_model['apple']
print("Vetor GloVe para a palavra 'apple':", word_vector)

# Encontrar palavras mais similares
similar_words = glove_model.most_similar('apple', topn=5)
print("Palavras mais similares a 'apple':", similar_words)
# Out:
# Vetor GloVe para a palavra 'apple': [-0.5985    -0.46321    0.13001   -0.019576   0.4603    -0.3018
#   0.8977    -0.65634    0.66858   -0.49164    0.037557  -0.050889
#   0.6451    -0.53882   -0.3765    -0.04312    0.51384    0.17783
#   0.28596    0.92063   -0.49349   -0.48583    0.61321    0.78211
#   0.19254    0.91228   -0.055596  -0.12512   -0.65688    0.068557
#   0.55629    1.611     -0.0073642 -0.48879    0.45493    0.96105
#  -0.063369   0.17432    0.9814    -1.3125    -0.15801   -0.54301
#  -0.13888   -0.26146   -0.3691     0.26844   -0.24375   -0.19484
#   0.62583   -0.7377     0.38351   -0.75004   -0.39053    0.091498
#  -0.36591   -1.4715    -0.45228    0.2256     1.1412    -0.38526
#  -0.06716    0.57288   -0.39191    0.31302   -0.29235   -0.96157
#   0.15154   -0.21659    0.25103    0.096967   0.2843     1.4296
#  -0.50565   -0.51374   -0.47218    0.32036    0.023149   0.22623
#  -0.09725    0.82126    0.92599   -1.0086    -0.38639    0.86408
# ...
